# %%
# !pip install faker
# Out:
# Collecting faker
#   Downloading Faker-24.1.0-py3-none-any.whl (1.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 7.7 MB/s eta 0:00:00
# Requirement already satisfied: python-dateutil>=2.4 in /usr/local/lib/python3.10/dist-packages (from faker) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.4->faker) (1.16.0)
# Installing collected packages: faker
# Successfully installed faker-24.1.0

# %%
import pandas as pd
import numpy as np
from faker import Faker
import random

faker = Faker()

def generate_text_by_category(category):
    """
    Generates synthetic text based on the provided category.
    """
    if category == 'Urgency':
        return faker.sentence(ext_word_list=['Hurry', 'Limited', 'Offer', 'Now', 'Exclusive'])
    else:
        return faker.sentence()

def create_synthetic_data(num_entries=100):
    """
    Creates a synthetic dataset with specified number of entries.
    """
    data = {
        'page_id': np.arange(1, num_entries + 1),
        'text': [],
        'label': np.random.randint(0, 2, num_entries),
        'Pattern Category': np.random.choice(['Urgency', 'Not Dark Pattern'], num_entries, p=[0.2, 0.8])
    }

    for category in data['Pattern Category']:
        data['text'].append(generate_text_by_category(category))

    return pd.DataFrame(data)

def save_data_to_csv(data, file_path):
    """
    Saves the DataFrame to a CSV file.
    """
    data.to_csv(file_path, index=False)
    print(f"Data saved to {file_path}")

synthetic_data = create_synthetic_data(num_entries=100)

# %%
synthetic_data.head()
# Out:
#    page_id                                               text  label  \
# 0        1  Smile difference while performance surface dif...      0
# 1        2     Exclusive Hurry Exclusive Hurry Offer Limited.      1
# 2        3                                 Field have sister.      1
# 3        4                     Now Limited Exclusive Now Now.      0
# 4        5  Easy actually into drug series money expect ho...      0
#
#    Pattern Category
# 0  Not Dark Pattern
# 1           Urgency
# 2  Not Dark Pattern
# 3           Urgency
# 4  Not Dark Pattern
